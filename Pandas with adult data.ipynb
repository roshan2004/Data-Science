# %%
import numpy as np
import pandas as pd

# %%
names = ['age', 'workclass', 'fnlwgt', 'education', 'educationnum', 'maritalstatus', 'occupation', 'relationship', 'race',
        'sex', 'capitalgain', 'capitalloss', 'hoursperweek', 'nativecountry', 'label']
# Read in the CSV file from the webpage using the defined column names
df1 = pd.read_csv("adult.csv", header=None, names=names)
df1.head()
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry   label
# 0         2174            0            40   United-States   <=50K
# ...

# %%
groups1 = df1.groupby('education')
groups1

# %%
for name, group in groups1:
    print('Education:{}'.format(name))
    print('{}\n'.format(group))
# Out:
# Education: 10th
#        age     workclass  fnlwgt education  educationnum        maritalstatus  \
# 77      67             ?  212759      10th             6   Married-civ-spouse
# 106     17             ?  304873      10th             6        Never-married
# 219     25       Private  255004      10th             6        Never-married
# 226     60             ?   24215      10th             6             Divorced
# 252     59     Local-gov  171328      10th             6              Widowed
# ...    ...           ...     ...       ...           ...                  ...
# 32505   33       Private  182401      10th             6        Never-married
# 32508   45       Private  155093      10th             6             Divorced
# 32515   66   Federal-gov   47358      10th             6   Married-civ-spouse
# 32526   32       Private  211349      10th             6   Married-civ-spouse
# 32551   32       Private   34066      10th             6   Married-civ-spouse
#
# ...

# %%
names = ['age', 'workclass', 'fnlwgt', 'education', 'educationnum', 'maritalstatus', 'occupation', 'relationship', 'race',
        'sex', 'capitalgain', 'capitalloss', 'hoursperweek', 'nativecountry', 'label']
# Read in the CSV file from the webpage using the defined column names
df = pd.read_csv("adult.csv", header=None, names=names)
df.head()
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry   label
# 0         2174            0            40   United-States   <=50K
# ...

# %%
type(df['workclass'])
# Out:
# pandas.core.series.Series

# %%
type(df[['workclass', 'education']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  educationnum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalstatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capitalloss  hoursperweek   nativecountry   label
# 0         2174            0            40   United-States   <=50K
# ...

# %%
if df.loc[::, 'age'].item =='?':
    print(True)

# %%
df.loc[16, 'workclass']
# Out:
# ' Self-emp-not-inc'

# %%
df.loc[1:20, 'workclass']
# Out:
# 1      Self-emp-not-inc
# 2               Private
# 3               Private
# 4               Private
# 5               Private
# 6               Private
# 7      Self-emp-not-inc
# 8               Private
# 9               Private
# 10              Private
# 11            State-gov
# 12              Private
# 13              Private
# 14              Private
# 15              Private
# 16     Self-emp-not-inc
# 17              Private
# 18              Private
# 19     Self-emp-not-inc
# 20              Private
# Name: workclass, dtype: object

# %%
df
# Out:
#        age          workclass  fnlwgt    education  educationnum  \
# 0       39          State-gov   77516    Bachelors            13
# 1       50   Self-emp-not-inc   83311    Bachelors            13
# 2       38            Private  215646      HS-grad             9
# 3       53            Private  234721         11th             7
# 4       28            Private  338409    Bachelors            13
# ...    ...                ...     ...          ...           ...
# 32556   27            Private  257302   Assoc-acdm            12
# 32557   40            Private  154374      HS-grad             9
# 32558   58            Private  151910      HS-grad             9
# 32559   22            Private  201490      HS-grad             9
# 32560   52       Self-emp-inc  287927      HS-grad             9
#
#              maritalstatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
pd.DataFrame(df.groupby('education'))
# Out:
#                 0                                                  1
# 0            10th         age     workclass  fnlwgt education  ed...
# 1            11th         age          workclass  fnlwgt educatio...
# 2            12th         age          workclass  fnlwgt educatio...
# 3         1st-4th         age workclass  fnlwgt education  educat...
# 4         5th-6th         age   workclass  fnlwgt education  educ...
# 5         7th-8th         age          workclass  fnlwgt educatio...
# 6             9th         age     workclass  fnlwgt education  ed...
# 7      Assoc-acdm         age          workclass  fnlwgt    educa...
# 8       Assoc-voc         age   workclass  fnlwgt   education  ed...
# 9       Bachelors         age          workclass  fnlwgt   educat...
# 10      Doctorate         age          workclass  fnlwgt   educat...
# 11        HS-grad         age          workclass  fnlwgt educatio...
# 12        Masters         age          workclass  fnlwgt educatio...
# ...

# %%
df = pd.read_csv('Teams.csv')
df.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP     FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ...  24  0.834
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ...  16  0.829
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19  ...  15  0.818
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12  ...   8  0.803
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17  ...  14  0.840
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    PPF  teamIDBR  teamIDlahman45  teamIDretro
# ...

# %%
groups = df.groupby('yearID')

print('{}\n'.format(groups.get_group(2016)))
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome    W    L  ...   DP  \
# 2805    2016   NL    ARI      ARI     W     4  162   81.0   69   93  ...  143
# 2806    2016   NL    ATL      ATL     E     5  161   81.0   68   93  ...  134
# 2807    2016   AL    BAL      BAL     E     2  162   81.0   89   73  ...  165
# 2808    2016   AL    BOS      BOS     E     1  162   81.0   93   69  ...  139
# 2809    2016   AL    CHA      CHW     C     4  162   81.0   78   84  ...  148
# 2810    2016   NL    CHN      CHC     C     1  162   81.0  103   58  ...  116
# 2811    2016   NL    CIN      CIN     C     5  162   81.0   68   94  ...  142
# 2812    2016   AL    CLE      CLE     C     1  161   80.0   94   67  ...  126
# 2813    2016   NL    COL      COL     W     3  162   81.0   75   87  ...  148
# 2814    2016   AL    DET      DET     C     2  161   81.0   86   75  ...  148
# 2815    2016   AL    HOU      HOU     W     3  162   81.0   84   78  ...  135
# ...

# %%
hello = groups.get_group(2016)
hello
# Out:
#      lgID teamID franchID divID  Rank    G  Ghome    W    L DivWin  ...   DP  \
# 2805   NL    ARI      ARI     W     4  162   81.0   69   93      N  ...  143
# 2806   NL    ATL      ATL     E     5  161   81.0   68   93      N  ...  134
# 2807   AL    BAL      BAL     E     2  162   81.0   89   73      N  ...  165
# 2808   AL    BOS      BOS     E     1  162   81.0   93   69      Y  ...  139
# 2809   AL    CHA      CHW     C     4  162   81.0   78   84      N  ...  148
# 2810   NL    CHN      CHC     C     1  162   81.0  103   58      Y  ...  116
# 2811   NL    CIN      CIN     C     5  162   81.0   68   94      N  ...  142
# 2812   AL    CLE      CLE     C     1  161   80.0   94   67      Y  ...  126
# 2813   NL    COL      COL     W     3  162   81.0   75   87      N  ...  148
# 2814   AL    DET      DET     C     2  161   81.0   86   75      N  ...  148
# 2815   AL    HOU      HOU     W     3  162   81.0   84   78      N  ...  135
# ...

# %%
hello.mean()
# Out:
# Rank          2.966667e+00
# G             1.618667e+02
# Ghome         8.093333e+01
# W             8.090000e+01
# L             8.090000e+01
# R             7.248000e+02
# AB            5.518700e+03
# H             1.409200e+03
# 2B            2.751333e+02
# 3B            2.910000e+01
# HR            1.870000e+02
# BB            5.029333e+02
# SO            1.299400e+03
# SB            8.456667e+01
# CS            3.336667e+01
# HBP           5.503333e+01
# SF            4.046667e+01
# RA            7.248000e+02
# ER            6.708000e+02
# ERA           4.184333e+00
# CG            2.766667e+00
# SHO           9.200000e+00
# SV            4.253333e+01
# IPouts        4.330633e+03
# HA            1.409200e+03
# HRA           1.870000e+02
# BBA           5.029333e+02
# SOA           1.299400e+03
# E             9.450000e+01
# DP            1.444667e+02
# FP            9.842000e-01
# attendance    2.438635e+06
# BPF           1.001667e+02
# PPF           1.001333e+02
# ...

# %%
groups

# %%
no2015 = groups.filter(lambda x: x.name > 2015)

# %%
# Out:
#      lgID teamID franchID divID  Rank    G  Ghome   W   L DivWin  ...   DP  \
# 2805   NL    ARI      ARI     W     4  162   81.0  69  93      N  ...  143
# 2806   NL    ATL      ATL     E     5  161   81.0  68  93      N  ...  134
# 2807   AL    BAL      BAL     E     2  162   81.0  89  73      N  ...  165
# 2808   AL    BOS      BOS     E     1  162   81.0  93  69      Y  ...  139
# 2809   AL    CHA      CHW     C     4  162   81.0  78  84      N  ...  148
# ...   ...    ...      ...   ...   ...  ...    ...  ..  ..    ...  ...  ...
# 2920   NL    SLN      STL     C     1  162   81.0  91  71      Y  ...  168
# 2921   AL    TBA      TBD     E     2  162   81.0  96  66      N  ...  126
# 2922   AL    TEX      TEX     W     3  162   81.0  78  84      N  ...  143
# 2923   AL    TOR      TOR     E     4  162   81.0  67  95      N  ...  141
# 2924   NL    WAS      WSN     E     2  162   81.0  93  69      N  ...  111
#
# ...

# %%
groups = df.groupby(['yearID', 'teamID'])

# %%
for name, group in groups:
    print('Year, Team: {}'.format(name))
    print('{}\n'.format(group))
# Out:
# Year, Team: (1871, 'BS1')
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP     FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ...  24  0.834
#
#                    name                 park  attendance  BPF  PPF  teamIDBR  \
# 0  Boston Red Stockings  South End Grounds I         NaN  103   98       BOS
#
#    teamIDlahman45  teamIDretro
# 0             BS1          BS1
#
# [1 rows x 48 columns]
#
# Year, Team: (1871, 'CH1')
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W  L  ...  DP     FP  \
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19  9  ...  16  0.829
#
#                       name                     park  attendance  BPF  PPF  \
# 1  Chicago White Stockings  Union Base-Ball Grounds         NaN  104  102
#
#    teamIDBR  teamIDlahman45  teamIDretro
# 1       CHI             CH1          CH1
#
# [1 rows x 48 columns]
#
# Year, Team: (1871, 'CL1')
# ...

# %%
groups.get_group((1908, 'NY1'))
# Out:
#      yearID lgID teamID franchID divID  Rank    G  Ghome   W   L  ...  DP  \
# 503    1908   NL    NY1      SFG   NaN     2  157   80.0  98  56  ...  79
#
#         FP             name              park  attendance  BPF  PPF  teamIDBR  \
# 503  0.962  New York Giants  Polo Grounds III    910000.0  105  102       NYG
#
#      teamIDlahman45  teamIDretro
# 503             NY1          NY1
#
# [1 rows x 48 columns]

# %%
df = pd.DataFrame({'T1': [10, 15, 8],
                  'T2' : [25, 27, 25],
                  'T3' : [16, 15, 10]})

# %%
df
# Out:
#    T1  T2  T3
# 0  10  25  16
# 1  15  27  15
# 2   8  25  10

# %%
df.sum(axis = 1) #Vary column, keep row constant # aggregate over columns
                # axis = 0, aggregate over rows, axis = 1, aggregate over columns
# Out:
# 0    51
# 1    57
# 2    43
# dtype: int64

# %%
df = pd.DataFrame({'T1': [0.1, 150], 'T2': [0.25, 240], 'T3': [0.16, 100]})
df
# Out:
#       T1      T2      T3
# 0    0.1    0.25    0.16
# 1  150.0  240.00  100.00

# %%
df
# Out:
#       T1      T2      T3
# 0    0.1    0.25    0.16
# 1  150.0  240.00  100.00

# %%
df.multiply(2)
# Out:
#       T1     T2      T3
# 0    0.2    0.5    0.32
# 1  300.0  480.0  200.00

# %%
df
# Out:
#       T1      T2      T3
# 0    0.1    0.25    0.16
# 1  150.0  240.00  100.00

# %%
df.multiply([2, 3, 4], axis =1)
# Out:
#       T1      T2      T3
# 0    0.2    0.75    0.64
# 1  300.0  720.00  400.00
